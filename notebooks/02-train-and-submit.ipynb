# %% [markdown]
# # Train and Submit (Notebook)
# Bu notebook CV eğitimi çalıştırır, OOF sonuçlarını kaydeder ve `submission.csv` üretir.

# %%
# !python src/run_pipeline.py --train train.csv --test test_x.csv --out submission.csv --model model.pkl --cv 5
